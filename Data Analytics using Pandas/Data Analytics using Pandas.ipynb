# %%
import pandas as pd

# %%
df = pd.read_csv("data/sales.csv")

# %%
calls_made = [10]* 20

# %%
df["Calls_Made"] = calls_made

# %%
df.head()
# Out:
#      Country Region Sales Person    Date of Purchase   Total  Quantity  \
# 0      India  North         John  11/18/2018 0:00:00  100000       567
# 1         US  North         Bill   2/24/2012 0:00:00  120000      3000
# 2         UK  North       Thomas  11/25/2011 0:00:00  140000       345
# 3  Australia   East         John    9/3/2014 0:00:00  160000      1000
# 4     Africa   East         Bill   1/14/2015 0:00:00  180000       123
#
#    Calls_Made
# 0          10
# 1          10
# 2          10
# 3          10
# 4          10

# %%
row = ["Poland", "North", "Charles", "12/19/2018 0:00:00", "75000","234","10"]

# %%
new_row = pd.DataFrame([row], columns = df.columns.values)

# %%
df.append(new_row)
# Out:
# C:\Users\gargm\AppData\Local\Temp\ipykernel_1308\3544121368.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(new_row)
#       Country Region Sales Person    Date of Purchase     Total Quantity  \
# 0       India  North         John  11/18/2018 0:00:00    100000      567
# 1          US  North         Bill   2/24/2012 0:00:00    120000     3000
# 2          UK  North       Thomas  11/25/2011 0:00:00    140000      345
# 3   Australia   East         John    9/3/2014 0:00:00    160000     1000
# 4      Africa   East         Bill   1/14/2015 0:00:00    180000      123
# 5   Singapore   East       Thomas    5/7/2011 0:00:00    200000     1000
# 6     Mylasia   West         John   3/28/2015 0:00:00   1000000     7890
# 7       India   West         Bill   7/23/2016 0:00:00    240000      200
# 8          US   West       Thomas   6/30/2016 0:00:00  26000000     1000
# 9          UK  North         John   7/10/2017 0:00:00    100000     1000
# 10  Australia  North         Bill   1/27/2012 0:00:00    120000      567
# 11     Africa  North       Thomas   12/3/2010 0:00:00    140000     1000
# 12  Singapore   East         John   6/13/2012 0:00:00    160000      892
# 13    Mylasia   East         Bill   6/30/2010 0:00:00    180000      444
# 14      India   East       Thomas   1/29/2012 0:00:00    200000       90
# 15         US   West         John   1/31/2015 0:00:00    220000       90
# 16         UK   West         Bill   8/20/2014 0:00:00    240000       90
# 17  Australia   West       Thomas    3/9/2017 0:00:00    260000       90
# 18     Africa  North         John    6/2/2016 0:00:00    140000       85
# 19  Singapore  North         Bill   5/23/2013 0:00:00    150000       85
# 0      Poland  North      Charles  12/19/2018 0:00:00     75000      234
#
#    Calls_Made
# 0          10
# 1          10
# 2          10
# 3          10
# 4          10
# 5          10
# 6          10
# 7          10
# 8          10
# 9          10
# 10         10
# 11         10
# 12         10
# 13         10
# 14         10
# 15         10
# 16         10
# 17         10
# 18         10
# 19         10
# 0          10

# %%
df
# Out:
#       Country Region Sales Person    Date of Purchase     Total  Quantity  \
# 0       India  North         John  11/18/2018 0:00:00    100000       567
# 1          US  North         Bill   2/24/2012 0:00:00    120000      3000
# 2          UK  North       Thomas  11/25/2011 0:00:00    140000       345
# 3   Australia   East         John    9/3/2014 0:00:00    160000      1000
# 4      Africa   East         Bill   1/14/2015 0:00:00    180000       123
# 5   Singapore   East       Thomas    5/7/2011 0:00:00    200000      1000
# 6     Mylasia   West         John   3/28/2015 0:00:00   1000000      7890
# 7       India   West         Bill   7/23/2016 0:00:00    240000       200
# 8          US   West       Thomas   6/30/2016 0:00:00  26000000      1000
# 9          UK  North         John   7/10/2017 0:00:00    100000      1000
# 10  Australia  North         Bill   1/27/2012 0:00:00    120000       567
# 11     Africa  North       Thomas   12/3/2010 0:00:00    140000      1000
# 12  Singapore   East         John   6/13/2012 0:00:00    160000       892
# 13    Mylasia   East         Bill   6/30/2010 0:00:00    180000       444
# 14      India   East       Thomas   1/29/2012 0:00:00    200000        90
# 15         US   West         John   1/31/2015 0:00:00    220000        90
# 16         UK   West         Bill   8/20/2014 0:00:00    240000        90
# 17  Australia   West       Thomas    3/9/2017 0:00:00    260000        90
# 18     Africa  North         John    6/2/2016 0:00:00    140000        85
# 19  Singapore  North         Bill   5/23/2013 0:00:00    150000        85
#
#     Calls_Made
# 0           10
# 1           10
# 2           10
# 3           10
# 4           10
# 5           10
# 6           10
# 7           10
# 8           10
# 9           10
# 10          10
# 11          10
# 12          10
# 13          10
# 14          10
# 15          10
# 16          10
# 17          10
# 18          10
# 19          10

# %%
po_numbers = [int(f"1000{i}") for i in range(20)]
import random 
random.shuffle(po_numbers)
po_numbers
# Out:
# [10003,
#  10005,
#  10004,
#  100017,
#  10001,
#  100011,
#  10008,
#  10009,
#  100016,
#  100012,
#  10002,
#  100013,
#  10000,
#  100014,
#  100015,
#  100018,
#  100019,
#  10006,
#  100010,
#  10007]

# %%
df["PO_Numbers"] = po_numbers

# %%
df.set_index("PO_Numbers", inplace = True)

# %%
df
# Out:
#               Country Region Sales Person    Date of Purchase     Total  \
# PO_Numbers
# 10003           India  North         John  11/18/2018 0:00:00    100000
# 10005              US  North         Bill   2/24/2012 0:00:00    120000
# 10004              UK  North       Thomas  11/25/2011 0:00:00    140000
# 100017      Australia   East         John    9/3/2014 0:00:00    160000
# 10001          Africa   East         Bill   1/14/2015 0:00:00    180000
# 100011      Singapore   East       Thomas    5/7/2011 0:00:00    200000
# 10008         Mylasia   West         John   3/28/2015 0:00:00   1000000
# 10009           India   West         Bill   7/23/2016 0:00:00    240000
# 100016             US   West       Thomas   6/30/2016 0:00:00  26000000
# 100012             UK  North         John   7/10/2017 0:00:00    100000
# 10002       Australia  North         Bill   1/27/2012 0:00:00    120000
# 100013         Africa  North       Thomas   12/3/2010 0:00:00    140000
# 10000       Singapore   East         John   6/13/2012 0:00:00    160000
# 100014        Mylasia   East         Bill   6/30/2010 0:00:00    180000
# 100015          India   East       Thomas   1/29/2012 0:00:00    200000
# 100018             US   West         John   1/31/2015 0:00:00    220000
# 100019             UK   West         Bill   8/20/2014 0:00:00    240000
# 10006       Australia   West       Thomas    3/9/2017 0:00:00    260000
# 100010         Africa  North         John    6/2/2016 0:00:00    140000
# 10007       Singapore  North         Bill   5/23/2013 0:00:00    150000
#
#             Quantity  Calls_Made
# PO_Numbers
# 10003            567          10
# 10005           3000          10
# 10004            345          10
# 100017          1000          10
# 10001            123          10
# 100011          1000          10
# 10008           7890          10
# 10009            200          10
# 100016          1000          10
# 100012          1000          10
# 10002            567          10
# 100013          1000          10
# 10000            892          10
# 100014           444          10
# 100015            90          10
# 100018            90          10
# 100019            90          10
# 10006             90          10
# 100010            85          10
# 10007             85          10

# %%
df.sort_values(["Country", "Region"], inplace=True)

# %%
pd.to_datetime(df["Date of Purchase"])
# Out:
# PO_Numbers
# 10001    2015-01-14
# 100013   2010-12-03
# 100010   2016-06-02
# 100017   2014-09-03
# 10002    2012-01-27
# 10006    2017-03-09
# 100015   2012-01-29
# 10003    2018-11-18
# 10009    2016-07-23
# 100014   2010-06-30
# 10008    2015-03-28
# 100011   2011-05-07
# 10000    2012-06-13
# 10007    2013-05-23
# 10004    2011-11-25
# 100012   2017-07-10
# 100019   2014-08-20
# 10005    2012-02-24
# 100016   2016-06-30
# 100018   2015-01-31
# Name: Date of Purchase, dtype: datetime64[ns]

# %%
df
# Out:
#               Country Region Sales Person    Date of Purchase     Total  \
# PO_Numbers
# 10001          Africa   East         Bill   1/14/2015 0:00:00    180000
# 100013         Africa  North       Thomas   12/3/2010 0:00:00    140000
# 100010         Africa  North         John    6/2/2016 0:00:00    140000
# 100017      Australia   East         John    9/3/2014 0:00:00    160000
# 10002       Australia  North         Bill   1/27/2012 0:00:00    120000
# 10006       Australia   West       Thomas    3/9/2017 0:00:00    260000
# 100015          India   East       Thomas   1/29/2012 0:00:00    200000
# 10003           India  North         John  11/18/2018 0:00:00    100000
# 10009           India   West         Bill   7/23/2016 0:00:00    240000
# 100014        Mylasia   East         Bill   6/30/2010 0:00:00    180000
# 10008         Mylasia   West         John   3/28/2015 0:00:00   1000000
# 100011      Singapore   East       Thomas    5/7/2011 0:00:00    200000
# 10000       Singapore   East         John   6/13/2012 0:00:00    160000
# 10007       Singapore  North         Bill   5/23/2013 0:00:00    150000
# 10004              UK  North       Thomas  11/25/2011 0:00:00    140000
# 100012             UK  North         John   7/10/2017 0:00:00    100000
# 100019             UK   West         Bill   8/20/2014 0:00:00    240000
# 10005              US  North         Bill   2/24/2012 0:00:00    120000
# 100016             US   West       Thomas   6/30/2016 0:00:00  26000000
# 100018             US   West         John   1/31/2015 0:00:00    220000
#
#             Quantity  Calls_Made
# PO_Numbers
# 10001            123          10
# 100013          1000          10
# 100010            85          10
# 100017          1000          10
# 10002            567          10
# 10006             90          10
# 100015            90          10
# 10003            567          10
# 10009            200          10
# 100014           444          10
# 10008           7890          10
# 100011          1000          10
# 10000            892          10
# 10007             85          10
# 10004            345          10
# 100012          1000          10
# 100019            90          10
# 10005           3000          10
# 100016          1000          10
# 100018            90          10

# %%
df["Date of Purchase"] = pd.to_datetime(df["Date of Purchase"])

# %%
df
# Out:
#               Country Region Sales Person Date of Purchase     Total  \
# PO_Numbers
# 10001          Africa   East         Bill       2015-01-14    180000
# 100013         Africa  North       Thomas       2010-12-03    140000
# 100010         Africa  North         John       2016-06-02    140000
# 100017      Australia   East         John       2014-09-03    160000
# 10002       Australia  North         Bill       2012-01-27    120000
# 10006       Australia   West       Thomas       2017-03-09    260000
# 100015          India   East       Thomas       2012-01-29    200000
# 10003           India  North         John       2018-11-18    100000
# 10009           India   West         Bill       2016-07-23    240000
# 100014        Mylasia   East         Bill       2010-06-30    180000
# 10008         Mylasia   West         John       2015-03-28   1000000
# 100011      Singapore   East       Thomas       2011-05-07    200000
# 10000       Singapore   East         John       2012-06-13    160000
# 10007       Singapore  North         Bill       2013-05-23    150000
# 10004              UK  North       Thomas       2011-11-25    140000
# 100012             UK  North         John       2017-07-10    100000
# 100019             UK   West         Bill       2014-08-20    240000
# 10005              US  North         Bill       2012-02-24    120000
# 100016             US   West       Thomas       2016-06-30  26000000
# 100018             US   West         John       2015-01-31    220000
#
#             Quantity  Calls_Made
# PO_Numbers
# 10001            123          10
# 100013          1000          10
# 100010            85          10
# 100017          1000          10
# 10002            567          10
# 10006             90          10
# 100015            90          10
# 10003            567          10
# 10009            200          10
# 100014           444          10
# 10008           7890          10
# 100011          1000          10
# 10000            892          10
# 10007             85          10
# 10004            345          10
# 100012          1000          10
# 100019            90          10
# 10005           3000          10
# 100016          1000          10
# 100018            90          10

# %%
df["Year"] = df["Date of Purchase"].dt.year

# %%
df
# Out:
#               Country Region Sales Person Date of Purchase     Total  \
# PO_Numbers
# 10001          Africa   East         Bill       2015-01-14    180000
# 100013         Africa  North       Thomas       2010-12-03    140000
# 100010         Africa  North         John       2016-06-02    140000
# 100017      Australia   East         John       2014-09-03    160000
# 10002       Australia  North         Bill       2012-01-27    120000
# 10006       Australia   West       Thomas       2017-03-09    260000
# 100015          India   East       Thomas       2012-01-29    200000
# 10003           India  North         John       2018-11-18    100000
# 10009           India   West         Bill       2016-07-23    240000
# 100014        Mylasia   East         Bill       2010-06-30    180000
# 10008         Mylasia   West         John       2015-03-28   1000000
# 100011      Singapore   East       Thomas       2011-05-07    200000
# 10000       Singapore   East         John       2012-06-13    160000
# 10007       Singapore  North         Bill       2013-05-23    150000
# 10004              UK  North       Thomas       2011-11-25    140000
# 100012             UK  North         John       2017-07-10    100000
# 100019             UK   West         Bill       2014-08-20    240000
# 10005              US  North         Bill       2012-02-24    120000
# 100016             US   West       Thomas       2016-06-30  26000000
# 100018             US   West         John       2015-01-31    220000
#
#             Quantity  Calls_Made  Year
# PO_Numbers
# 10001            123          10  2015
# 100013          1000          10  2010
# 100010            85          10  2016
# 100017          1000          10  2014
# 10002            567          10  2012
# 10006             90          10  2017
# 100015            90          10  2012
# 10003            567          10  2018
# 10009            200          10  2016
# 100014           444          10  2010
# 10008           7890          10  2015
# 100011          1000          10  2011
# 10000            892          10  2012
# 10007             85          10  2013
# 10004            345          10  2011
# 100012          1000          10  2017
# 100019            90          10  2014
# 10005           3000          10  2012
# 100016          1000          10  2016
# 100018            90          10  2015

# %%
#Math Functions
#sum
#min
#max
#mean
#variance
#percentage
#generating new columns
#correlation
#absolute

# %%
df["Total"].min()
# Out:
# 100000

# %%
df[["Total","Quantity"]].max()
# Out:
# Total       26000000
# Quantity        7890
# dtype: int64

# %%
df.mean()
# Out:
# C:\Users\gargm\AppData\Local\Temp\ipykernel_1308\3698961737.py:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.mean()
# C:\Users\gargm\AppData\Local\Temp\ipykernel_1308\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# Total         1502500.0
# Quantity          977.9
# Calls_Made         10.0
# Year             2013.8
# dtype: float64

# %%
df.max()
# Out:
# Country                              US
# Region                             West
# Sales Person                     Thomas
# Date of Purchase    2018-11-18 00:00:00
# Total                          26000000
# Quantity                           7890
# Calls_Made                           10
# Year                               2018
# dtype: object

# %%
df.min()
# Out:
# Country                          Africa
# Region                             East
# Sales Person                       Bill
# Date of Purchase    2010-06-30 00:00:00
# Total                            100000
# Quantity                             85
# Calls_Made                           10
# Year                               2010
# dtype: object

# %%
df["Sales Person"][df["Total"]==df["Total"].max()]
# Out:
# PO_Numbers
# 100016    Thomas
# Name: Sales Person, dtype: object

# %%
df["Selling Ratio"] = df["Total"] / df["Quantity"]

# %%
df
# Out:
#               Country Region Sales Person Date of Purchase     Total  \
# PO_Numbers
# 10001          Africa   East         Bill       2015-01-14    180000
# 100013         Africa  North       Thomas       2010-12-03    140000
# 100010         Africa  North         John       2016-06-02    140000
# 100017      Australia   East         John       2014-09-03    160000
# 10002       Australia  North         Bill       2012-01-27    120000
# 10006       Australia   West       Thomas       2017-03-09    260000
# 100015          India   East       Thomas       2012-01-29    200000
# 10003           India  North         John       2018-11-18    100000
# 10009           India   West         Bill       2016-07-23    240000
# 100014        Mylasia   East         Bill       2010-06-30    180000
# 10008         Mylasia   West         John       2015-03-28   1000000
# 100011      Singapore   East       Thomas       2011-05-07    200000
# 10000       Singapore   East         John       2012-06-13    160000
# 10007       Singapore  North         Bill       2013-05-23    150000
# 10004              UK  North       Thomas       2011-11-25    140000
# 100012             UK  North         John       2017-07-10    100000
# 100019             UK   West         Bill       2014-08-20    240000
# 10005              US  North         Bill       2012-02-24    120000
# 100016             US   West       Thomas       2016-06-30  26000000
# 100018             US   West         John       2015-01-31    220000
#
#             Quantity  Calls_Made  Year  Selling Ratio
# PO_Numbers
# 10001            123          10  2015    1463.414634
# 100013          1000          10  2010     140.000000
# 100010            85          10  2016    1647.058824
# 100017          1000          10  2014     160.000000
# 10002            567          10  2012     211.640212
# 10006             90          10  2017    2888.888889
# 100015            90          10  2012    2222.222222
# 10003            567          10  2018     176.366843
# 10009            200          10  2016    1200.000000
# 100014           444          10  2010     405.405405
# 10008           7890          10  2015     126.742712
# 100011          1000          10  2011     200.000000
# 10000            892          10  2012     179.372197
# 10007             85          10  2013    1764.705882
# 10004            345          10  2011     405.797101
# 100012          1000          10  2017     100.000000
# 100019            90          10  2014    2666.666667
# 10005           3000          10  2012      40.000000
# 100016          1000          10  2016   26000.000000
# 100018            90          10  2015    2444.444444

# %%
df[["Sales Person", "Total","Quantity","Selling Ratio"]][df["Selling Ratio"]==df["Selling Ratio"].max()]
# Out:
#            Sales Person     Total  Quantity  Selling Ratio
# PO_Numbers
# 100016           Thomas  26000000      1000        26000.0

# %%
df[["Sales Person", "Total","Quantity","Selling Ratio"]][df["Selling Ratio"]==df["Selling Ratio"].min()]
# Out:
#            Sales Person   Total  Quantity  Selling Ratio
# PO_Numbers
# 10005              Bill  120000      3000           40.0

# %%
df["Bonus"] = df["Total"]/10

# %%
df[["Total", "Quantity", "Selling Ratio", "Bonus"]].corr()
# Out:
#                   Total  Quantity  Selling Ratio     Bonus
# Total          1.000000  0.031260       0.984196  1.000000
# Quantity       0.031260  1.000000      -0.070494  0.031260
# Selling Ratio  0.984196 -0.070494       1.000000  0.984196
# Bonus          1.000000  0.031260       0.984196  1.000000

# %%
df = pd.read_csv("data/sales.csv")

# %%
df
# Out:
#       Country Region Sales Person    Date of Purchase     Total  Quantity
# 0       India  North         John  11/18/2018 0:00:00    100000       567
# 1          US  North         Bill   2/24/2012 0:00:00    120000      3000
# 2          UK  North       Thomas  11/25/2011 0:00:00    140000       345
# 3   Australia   East         John    9/3/2014 0:00:00    160000      1000
# 4      Africa   East         Bill   1/14/2015 0:00:00    180000       123
# 5   Singapore   East       Thomas    5/7/2011 0:00:00    200000      1000
# 6     Mylasia   West         John   3/28/2015 0:00:00   1000000      7890
# 7       India   West         Bill   7/23/2016 0:00:00    240000       200
# 8          US   West       Thomas   6/30/2016 0:00:00  26000000      1000
# 9          UK  North         John   7/10/2017 0:00:00    100000      1000
# 10  Australia  North         Bill   1/27/2012 0:00:00    120000       567
# 11     Africa  North       Thomas   12/3/2010 0:00:00    140000      1000
# 12  Singapore   East         John   6/13/2012 0:00:00    160000       892
# 13    Mylasia   East         Bill   6/30/2010 0:00:00    180000       444
# 14      India   East       Thomas   1/29/2012 0:00:00    200000        90
# 15         US   West         John   1/31/2015 0:00:00    220000        90
# 16         UK   West         Bill   8/20/2014 0:00:00    240000        90
# 17  Australia   West       Thomas    3/9/2017 0:00:00    260000        90
# 18     Africa  North         John    6/2/2016 0:00:00    140000        85
# 19  Singapore  North         Bill   5/23/2013 0:00:00    150000        85

# %%
po_numbers = [int(f"1000{i}") for i in range(20)]

# %%
df["PO Numbers"] = po_numbers

# %%
df.head()
# Out:
#      Country Region Sales Person    Date of Purchase   Total  Quantity  \
# 0      India  North         John  11/18/2018 0:00:00  100000       567
# 1         US  North         Bill   2/24/2012 0:00:00  120000      3000
# 2         UK  North       Thomas  11/25/2011 0:00:00  140000       345
# 3  Australia   East         John    9/3/2014 0:00:00  160000      1000
# 4     Africa   East         Bill   1/14/2015 0:00:00  180000       123
#
#    PO Numbers
# 0       10000
# 1       10001
# 2       10002
# 3       10003
# 4       10004

# %%
df.reset_index(inplace=True)

# %%
df.set_index("PO Numbers", inplace=True)

# %%
df.head()
# Out:
#             index    Country Region Sales Person    Date of Purchase   Total  \
# PO Numbers
# 10000           0      India  North         John  11/18/2018 0:00:00  100000
# 10001           1         US  North         Bill   2/24/2012 0:00:00  120000
# 10002           2         UK  North       Thomas  11/25/2011 0:00:00  140000
# 10003           3  Australia   East         John    9/3/2014 0:00:00  160000
# 10004           4     Africa   East         Bill   1/14/2015 0:00:00  180000
#
#             Quantity
# PO Numbers
# 10000            567
# 10001           3000
# 10002            345
# 10003           1000
# 10004            123

# %%
df.loc[10009]
# Out:
# index                               9
# Country                            UK
# Region                          North
# Sales Person                     John
# Date of Purchase    7/10/2017 0:00:00
# Total                          100000
# Quantity                         1000
# Name: 10009, dtype: object

# %%
df["Date of Purchase"] = pd.to_datetime(df["Date of Purchase"])
df["Selling Ratio"] = df["Total"] / df["Quantity"]
df["Bonus"] = df["Total"]/10

# %%
df.head()
# Out:
#             index    Country Region Sales Person Date of Purchase   Total  \
# PO Numbers
# 10000           0      India  North         John       2018-11-18  100000
# 10001           1         US  North         Bill       2012-02-24  120000
# 10002           2         UK  North       Thomas       2011-11-25  140000
# 10003           3  Australia   East         John       2014-09-03  160000
# 10004           4     Africa   East         Bill       2015-01-14  180000
#
#             Quantity  Selling Ratio    Bonus
# PO Numbers
# 10000            567     176.366843  10000.0
# 10001           3000      40.000000  12000.0
# 10002            345     405.797101  14000.0
# 10003           1000     160.000000  16000.0
# 10004            123    1463.414634  18000.0

# %%
#Grouping

# %%
df.groupby("Country").sum()
# Out:
#            index     Total  Quantity  Selling Ratio      Bonus
# Country
# Africa        33    460000      1208    3250.473458    46000.0
# Australia     30    540000      1657    3260.529101    54000.0
# India         21    540000       857    3598.589065    54000.0
# Mylasia       19   1180000      8334     532.148118   118000.0
# Singapore     36    510000      1977    2144.078080    51000.0
# UK            27    480000      1435    3172.463768    48000.0
# US            24  26340000      4090   28484.444444  2634000.0

# %%
df.groupby("Country").min()
# Out:
#            index Region Sales Person Date of Purchase   Total  Quantity  \
# Country
# Africa         4   East         Bill       2010-12-03  140000        85
# Australia      3   East         Bill       2012-01-27  120000        90
# India          0   East         Bill       2012-01-29  100000        90
# Mylasia        6   East         Bill       2010-06-30  180000       444
# Singapore      5   East         Bill       2011-05-07  150000        85
# UK             2  North         Bill       2011-11-25  100000        90
# US             1  North         Bill       2012-02-24  120000        90
#
#            Selling Ratio    Bonus
# Country
# Africa        140.000000  14000.0
# Australia     160.000000  12000.0
# India         176.366843  10000.0
# Mylasia       126.742712  18000.0
# Singapore     179.372197  15000.0
# UK            100.000000  10000.0
# US             40.000000  12000.0

# %%
df.groupby(["Country","Region","Sales Person"])["Total","Quantity"].sum()
# Out:
# C:\Users\gargm\AppData\Local\Temp\ipykernel_1308\2722450960.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(["Country","Region","Sales Person"])["Total","Quantity"].sum()
#                                   Total  Quantity
# Country   Region Sales Person
# Africa    East   Bill            180000       123
#           North  John            140000        85
#                  Thomas          140000      1000
# Australia East   John            160000      1000
#           North  Bill            120000       567
#           West   Thomas          260000        90
# India     East   Thomas          200000        90
#           North  John            100000       567
#           West   Bill            240000       200
# Mylasia   East   Bill            180000       444
#           West   John           1000000      7890
# Singapore East   John            160000       892
#                  Thomas          200000      1000
#           North  Bill            150000        85
# UK        North  John            100000      1000
#                  Thomas          140000       345
#           West   Bill            240000        90
# US        North  Bill            120000      3000
#           West   John            220000        90
#                  Thomas        26000000      1000

# %%
df.groupby(df["Date of Purchase"].dt.year)["Total","Quantity"].sum()
# Out:
# C:\Users\gargm\AppData\Local\Temp\ipykernel_15684\1634857282.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(df["Date of Purchase"].dt.year)["Total","Quantity"].sum()
#                      Total  Quantity
# Date of Purchase
# 2010                320000      1444
# 2011                340000      1345
# 2012                600000      4549
# 2013                150000        85
# 2014                400000      1090
# 2015               1400000      8103
# 2016              26380000      1285
# 2017                360000      1090
# 2018                100000       567

# %%
df.groupby(df["Date of Purchase"].dt.year)["Total"].agg(["sum", "mean"])
# Out:
#                        sum          mean
# Date of Purchase
# 2010                320000  1.600000e+05
# 2011                340000  1.700000e+05
# 2012                600000  1.500000e+05
# 2013                150000  1.500000e+05
# 2014                400000  2.000000e+05
# 2015               1400000  4.666667e+05
# 2016              26380000  8.793333e+06
# 2017                360000  1.800000e+05
# 2018                100000  1.000000e+05

# %%
##GRAPHS

#TYPES
- bar
- line
- pie
- scatter

#PROPERTIES
- title
- label
- colour

#SPECIAL EFFECTS
- Heatmap

# %%
groupby_df = df.groupby(["Country"])[["Total"]].sum()
groupby_df
# Out:
#               Total
# Country
# Africa       460000
# Australia    540000
# India        540000
# Mylasia     1180000
# Singapore    510000
# UK           480000
# US         26340000

# %%
groupby_df.plot.pie(subplots=True)
# Out:
# array([<AxesSubplot:ylabel='Total'>], dtype=object)

# %%
groupby_df.plot.bar(color = "green", title = "Sales / Country")
# Out:
# <AxesSubplot:title={'center':'Sales / Country'}, xlabel='Country'>

# %%
import seaborn as sns

# %%
corr = df[["Total", "Quantity", "Selling Ratio", "Bonus"]].corr()
corr
# Out:
#                 Total  Quantity  Selling Ratio   Bonus
# Total         1.00000   0.03126        0.98420 1.00000
# Quantity      0.03126   1.00000       -0.07049 0.03126
# Selling Ratio 0.98420  -0.07049        1.00000 0.98420
# Bonus         1.00000   0.03126        0.98420 1.00000

# %%
sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>

# %%
# merge and join - different df - overlapping
# concatenate and append - new rows and/or columns

# %%
df = df = pd.read_csv("data/sales.csv")

# %%
new_df = pd.DataFrame()
new_df["Employee Name"] = df["Sales Person"].unique()

import random
exp= [1,2,4]
random.shuffle(exp)

new_df["Experience in Company"] = exp
new_df["Total Experience"] = new_df["Experience in Company"] + random.randint(1,10)

new_df
# Out:
#   Employee Name  Experience in Company  Total Experience
# 0          John                      2                 7
# 1          Bill                      4                 9
# 2        Thomas                      1                 6

# %%
df.merge(new_df, left_on="Sales Person", right_on = "Employee Name")
# Out:
#    Sales Person  index    Country Region Date of Purchase     Total  Quantity  \
# 0          John      0      India  North       2018-11-18    100000       567
# 1          John      3  Australia   East       2014-09-03    160000      1000
# 2          John      6    Mylasia   West       2015-03-28   1000000      7890
# 3          John      9         UK  North       2017-07-10    100000      1000
# 4          John     12  Singapore   East       2012-06-13    160000       892
# 5          John     15         US   West       2015-01-31    220000        90
# 6          John     18     Africa  North       2016-06-02    140000        85
# 7          Bill      1         US  North       2012-02-24    120000      3000
# 8          Bill      4     Africa   East       2015-01-14    180000       123
# 9          Bill      7      India   West       2016-07-23    240000       200
# 10         Bill     10  Australia  North       2012-01-27    120000       567
# 11         Bill     13    Mylasia   East       2010-06-30    180000       444
# 12         Bill     16         UK   West       2014-08-20    240000        90
# 13         Bill     19  Singapore  North       2013-05-23    150000        85
# 14       Thomas      2         UK  North       2011-11-25    140000       345
# 15       Thomas      5  Singapore   East       2011-05-07    200000      1000
# 16       Thomas      8         US   West       2016-06-30  26000000      1000
# 17       Thomas     11     Africa  North       2010-12-03    140000      1000
# 18       Thomas     14      India   East       2012-01-29    200000        90
# 19       Thomas     17  Australia   West       2017-03-09    260000        90
#
#     Selling Ratio         Bonus Employee Name  Experience in Company  \
# 0       176.36684   10000.00000          John                      2
# 1       160.00000   16000.00000          John                      2
# 2       126.74271  100000.00000          John                      2
# 3       100.00000   10000.00000          John                      2
# 4       179.37220   16000.00000          John                      2
# 5      2444.44444   22000.00000          John                      2
# 6      1647.05882   14000.00000          John                      2
# 7        40.00000   12000.00000          Bill                      1
# 8      1463.41463   18000.00000          Bill                      1
# 9      1200.00000   24000.00000          Bill                      1
# 10      211.64021   12000.00000          Bill                      1
# 11      405.40541   18000.00000          Bill                      1
# 12     2666.66667   24000.00000          Bill                      1
# 13     1764.70588   15000.00000          Bill                      1
# 14      405.79710   14000.00000        Thomas                      4
# 15      200.00000   20000.00000        Thomas                      4
# 16    26000.00000 2600000.00000        Thomas                      4
# 17      140.00000   14000.00000        Thomas                      4
# 18     2222.22222   20000.00000        Thomas                      4
# 19     2888.88889   26000.00000        Thomas                      4
#
#     Total Experience
# 0                  9
# 1                  9
# 2                  9
# 3                  9
# 4                  9
# 5                  9
# 6                  9
# 7                  8
# 8                  8
# 9                  8
# 10                 8
# 11                 8
# 12                 8
# 13                 8
# 14                11
# 15                11
# 16                11
# 17                11
# 18                11
# 19                11

# %%
df.merge(new_df, left_on="Sales Person", right_on = "Employee Name").drop("Employee Name", axis=1)
# Out:
#       Country Region Sales Person    Date of Purchase     Total  Quantity  \
# 0       India  North         John  11/18/2018 0:00:00    100000       567
# 1   Australia   East         John    9/3/2014 0:00:00    160000      1000
# 2     Mylasia   West         John   3/28/2015 0:00:00   1000000      7890
# 3          UK  North         John   7/10/2017 0:00:00    100000      1000
# 4   Singapore   East         John   6/13/2012 0:00:00    160000       892
# 5          US   West         John   1/31/2015 0:00:00    220000        90
# 6      Africa  North         John    6/2/2016 0:00:00    140000        85
# 7          US  North         Bill   2/24/2012 0:00:00    120000      3000
# 8      Africa   East         Bill   1/14/2015 0:00:00    180000       123
# 9       India   West         Bill   7/23/2016 0:00:00    240000       200
# 10  Australia  North         Bill   1/27/2012 0:00:00    120000       567
# 11    Mylasia   East         Bill   6/30/2010 0:00:00    180000       444
# 12         UK   West         Bill   8/20/2014 0:00:00    240000        90
# 13  Singapore  North         Bill   5/23/2013 0:00:00    150000        85
# 14         UK  North       Thomas  11/25/2011 0:00:00    140000       345
# 15  Singapore   East       Thomas    5/7/2011 0:00:00    200000      1000
# 16         US   West       Thomas   6/30/2016 0:00:00  26000000      1000
# 17     Africa  North       Thomas   12/3/2010 0:00:00    140000      1000
# 18      India   East       Thomas   1/29/2012 0:00:00    200000        90
# 19  Australia   West       Thomas    3/9/2017 0:00:00    260000        90
#
#     Experience in Company  Total Experience
# 0                       2                 7
# 1                       2                 7
# 2                       2                 7
# 3                       2                 7
# 4                       2                 7
# 5                       2                 7
# 6                       2                 7
# 7                       4                 9
# 8                       4                 9
# 9                       4                 9
# 10                      4                 9
# 11                      4                 9
# 12                      4                 9
# 13                      4                 9
# 14                      1                 6
# 15                      1                 6
# 16                      1                 6
# 17                      1                 6
# 18                      1                 6
# 19                      1                 6

# %%
df.set_index("Sales Person", inplace=True)
new_df.set_index("Employee Name", inplace=True)

# %%
df.join(new_df)
# Out:
#           Country Region    Date of Purchase     Total  Quantity  \
# Bill           US  North   2/24/2012 0:00:00    120000      3000
# Bill       Africa   East   1/14/2015 0:00:00    180000       123
# Bill        India   West   7/23/2016 0:00:00    240000       200
# Bill    Australia  North   1/27/2012 0:00:00    120000       567
# Bill      Mylasia   East   6/30/2010 0:00:00    180000       444
# Bill           UK   West   8/20/2014 0:00:00    240000        90
# Bill    Singapore  North   5/23/2013 0:00:00    150000        85
# John        India  North  11/18/2018 0:00:00    100000       567
# John    Australia   East    9/3/2014 0:00:00    160000      1000
# John      Mylasia   West   3/28/2015 0:00:00   1000000      7890
# John           UK  North   7/10/2017 0:00:00    100000      1000
# John    Singapore   East   6/13/2012 0:00:00    160000       892
# John           US   West   1/31/2015 0:00:00    220000        90
# John       Africa  North    6/2/2016 0:00:00    140000        85
# Thomas         UK  North  11/25/2011 0:00:00    140000       345
# Thomas  Singapore   East    5/7/2011 0:00:00    200000      1000
# Thomas         US   West   6/30/2016 0:00:00  26000000      1000
# Thomas     Africa  North   12/3/2010 0:00:00    140000      1000
# Thomas      India   East   1/29/2012 0:00:00    200000        90
# Thomas  Australia   West    3/9/2017 0:00:00    260000        90
#
#         Experience in Company  Total Experience
# Bill                        4                 9
# Bill                        4                 9
# Bill                        4                 9
# Bill                        4                 9
# Bill                        4                 9
# Bill                        4                 9
# Bill                        4                 9
# John                        2                 7
# John                        2                 7
# John                        2                 7
# John                        2                 7
# John                        2                 7
# John                        2                 7
# John                        2                 7
# Thomas                      1                 6
# Thomas                      1                 6
# Thomas                      1                 6
# Thomas                      1                 6
# Thomas                      1                 6
# Thomas                      1                 6

# %%
df = df.reset_index()
df
# Out:
#     index Sales Person    Country Region    Date of Purchase     Total  \
# 0       0         John      India  North  11/18/2018 0:00:00    100000
# 1       1         Bill         US  North   2/24/2012 0:00:00    120000
# 2       2       Thomas         UK  North  11/25/2011 0:00:00    140000
# 3       3         John  Australia   East    9/3/2014 0:00:00    160000
# 4       4         Bill     Africa   East   1/14/2015 0:00:00    180000
# 5       5       Thomas  Singapore   East    5/7/2011 0:00:00    200000
# 6       6         John    Mylasia   West   3/28/2015 0:00:00   1000000
# 7       7         Bill      India   West   7/23/2016 0:00:00    240000
# 8       8       Thomas         US   West   6/30/2016 0:00:00  26000000
# 9       9         John         UK  North   7/10/2017 0:00:00    100000
# 10     10         Bill  Australia  North   1/27/2012 0:00:00    120000
# 11     11       Thomas     Africa  North   12/3/2010 0:00:00    140000
# 12     12         John  Singapore   East   6/13/2012 0:00:00    160000
# 13     13         Bill    Mylasia   East   6/30/2010 0:00:00    180000
# 14     14       Thomas      India   East   1/29/2012 0:00:00    200000
# 15     15         John         US   West   1/31/2015 0:00:00    220000
# 16     16         Bill         UK   West   8/20/2014 0:00:00    240000
# 17     17       Thomas  Australia   West    3/9/2017 0:00:00    260000
# 18     18         John     Africa  North    6/2/2016 0:00:00    140000
# 19     19         Bill  Singapore  North   5/23/2013 0:00:00    150000
#
#     Quantity
# 0        567
# 1       3000
# 2        345
# 3       1000
# 4        123
# 5       1000
# 6       7890
# 7        200
# 8       1000
# 9       1000
# 10       567
# 11      1000
# 12       892
# 13       444
# 14        90
# 15        90
# 16        90
# 17        90
# 18        85
# 19        85

# %%
new_df = df.copy()
new_df1 = df.copy()
new_df2 = df.copy()

# %%
pd.concat([new_df, new_df1, new_df2],ignore_index =True)
# Out:
#     index Sales Person    Country Region    Date of Purchase     Total  \
# 0       0         John      India  North  11/18/2018 0:00:00    100000
# 1       1         Bill         US  North   2/24/2012 0:00:00    120000
# 2       2       Thomas         UK  North  11/25/2011 0:00:00    140000
# 3       3         John  Australia   East    9/3/2014 0:00:00    160000
# 4       4         Bill     Africa   East   1/14/2015 0:00:00    180000
# 5       5       Thomas  Singapore   East    5/7/2011 0:00:00    200000
# 6       6         John    Mylasia   West   3/28/2015 0:00:00   1000000
# 7       7         Bill      India   West   7/23/2016 0:00:00    240000
# 8       8       Thomas         US   West   6/30/2016 0:00:00  26000000
# 9       9         John         UK  North   7/10/2017 0:00:00    100000
# 10     10         Bill  Australia  North   1/27/2012 0:00:00    120000
# 11     11       Thomas     Africa  North   12/3/2010 0:00:00    140000
# 12     12         John  Singapore   East   6/13/2012 0:00:00    160000
# 13     13         Bill    Mylasia   East   6/30/2010 0:00:00    180000
# 14     14       Thomas      India   East   1/29/2012 0:00:00    200000
# 15     15         John         US   West   1/31/2015 0:00:00    220000
# 16     16         Bill         UK   West   8/20/2014 0:00:00    240000
# 17     17       Thomas  Australia   West    3/9/2017 0:00:00    260000
# 18     18         John     Africa  North    6/2/2016 0:00:00    140000
# 19     19         Bill  Singapore  North   5/23/2013 0:00:00    150000
# 20      0         John      India  North  11/18/2018 0:00:00    100000
# 21      1         Bill         US  North   2/24/2012 0:00:00    120000
# 22      2       Thomas         UK  North  11/25/2011 0:00:00    140000
# 23      3         John  Australia   East    9/3/2014 0:00:00    160000
# 24      4         Bill     Africa   East   1/14/2015 0:00:00    180000
# 25      5       Thomas  Singapore   East    5/7/2011 0:00:00    200000
# 26      6         John    Mylasia   West   3/28/2015 0:00:00   1000000
# 27      7         Bill      India   West   7/23/2016 0:00:00    240000
# 28      8       Thomas         US   West   6/30/2016 0:00:00  26000000
# 29      9         John         UK  North   7/10/2017 0:00:00    100000
# 30     10         Bill  Australia  North   1/27/2012 0:00:00    120000
# 31     11       Thomas     Africa  North   12/3/2010 0:00:00    140000
# 32     12         John  Singapore   East   6/13/2012 0:00:00    160000
# 33     13         Bill    Mylasia   East   6/30/2010 0:00:00    180000
# 34     14       Thomas      India   East   1/29/2012 0:00:00    200000
# 35     15         John         US   West   1/31/2015 0:00:00    220000
# 36     16         Bill         UK   West   8/20/2014 0:00:00    240000
# 37     17       Thomas  Australia   West    3/9/2017 0:00:00    260000
# 38     18         John     Africa  North    6/2/2016 0:00:00    140000
# 39     19         Bill  Singapore  North   5/23/2013 0:00:00    150000
# 40      0         John      India  North  11/18/2018 0:00:00    100000
# 41      1         Bill         US  North   2/24/2012 0:00:00    120000
# 42      2       Thomas         UK  North  11/25/2011 0:00:00    140000
# 43      3         John  Australia   East    9/3/2014 0:00:00    160000
# 44      4         Bill     Africa   East   1/14/2015 0:00:00    180000
# 45      5       Thomas  Singapore   East    5/7/2011 0:00:00    200000
# 46      6         John    Mylasia   West   3/28/2015 0:00:00   1000000
# 47      7         Bill      India   West   7/23/2016 0:00:00    240000
# 48      8       Thomas         US   West   6/30/2016 0:00:00  26000000
# 49      9         John         UK  North   7/10/2017 0:00:00    100000
# 50     10         Bill  Australia  North   1/27/2012 0:00:00    120000
# 51     11       Thomas     Africa  North   12/3/2010 0:00:00    140000
# 52     12         John  Singapore   East   6/13/2012 0:00:00    160000
# 53     13         Bill    Mylasia   East   6/30/2010 0:00:00    180000
# 54     14       Thomas      India   East   1/29/2012 0:00:00    200000
# 55     15         John         US   West   1/31/2015 0:00:00    220000
# 56     16         Bill         UK   West   8/20/2014 0:00:00    240000
# 57     17       Thomas  Australia   West    3/9/2017 0:00:00    260000
# 58     18         John     Africa  North    6/2/2016 0:00:00    140000
# 59     19         Bill  Singapore  North   5/23/2013 0:00:00    150000
#
#     Quantity
# 0        567
# 1       3000
# 2        345
# 3       1000
# 4        123
# 5       1000
# 6       7890
# 7        200
# 8       1000
# 9       1000
# 10       567
# 11      1000
# 12       892
# 13       444
# 14        90
# 15        90
# 16        90
# 17        90
# 18        85
# 19        85
# 20       567
# 21      3000
# 22       345
# 23      1000
# 24       123
# 25      1000
# 26      7890
# 27       200
# 28      1000
# 29      1000
# 30       567
# 31      1000
# 32       892
# 33       444
# 34        90
# 35        90
# 36        90
# 37        90
# 38        85
# 39        85
# 40       567
# 41      3000
# 42       345
# 43      1000
# 44       123
# 45      1000
# 46      7890
# 47       200
# 48      1000
# 49      1000
# 50       567
# 51      1000
# 52       892
# 53       444
# 54        90
# 55        90
# 56        90
# 57        90
# 58        85
# 59        85

# %%
pd.concat([new_df, new_df1, new_df2],axis=1)
# Out:
#     index  Sales Person    Country Region    Date of Purchase     Total  \
# 0       0          John      India  North  11/18/2018 0:00:00    100000
# 1       1          Bill         US  North   2/24/2012 0:00:00    120000
# 2       2        Thomas         UK  North  11/25/2011 0:00:00    140000
# 3       3          John  Australia   East    9/3/2014 0:00:00    160000
# 4       4          Bill     Africa   East   1/14/2015 0:00:00    180000
# 5       5        Thomas  Singapore   East    5/7/2011 0:00:00    200000
# 6       6          John    Mylasia   West   3/28/2015 0:00:00   1000000
# 7       7          Bill      India   West   7/23/2016 0:00:00    240000
# 8       8        Thomas         US   West   6/30/2016 0:00:00  26000000
# 9       9          John         UK  North   7/10/2017 0:00:00    100000
# 10     10          Bill  Australia  North   1/27/2012 0:00:00    120000
# 11     11        Thomas     Africa  North   12/3/2010 0:00:00    140000
# 12     12          John  Singapore   East   6/13/2012 0:00:00    160000
# 13     13          Bill    Mylasia   East   6/30/2010 0:00:00    180000
# 14     14        Thomas      India   East   1/29/2012 0:00:00    200000
# 15     15          John         US   West   1/31/2015 0:00:00    220000
# 16     16          Bill         UK   West   8/20/2014 0:00:00    240000
# 17     17        Thomas  Australia   West    3/9/2017 0:00:00    260000
# 18     18          John     Africa  North    6/2/2016 0:00:00    140000
# 19     19          Bill  Singapore  North   5/23/2013 0:00:00    150000
#
#     Quantity  index  Sales Person    Country  ...    Date of Purchase  \
# 0        567      0          John      India  ...  11/18/2018 0:00:00
# 1       3000      1          Bill         US  ...   2/24/2012 0:00:00
# 2        345      2        Thomas         UK  ...  11/25/2011 0:00:00
# 3       1000      3          John  Australia  ...    9/3/2014 0:00:00
# 4        123      4          Bill     Africa  ...   1/14/2015 0:00:00
# 5       1000      5        Thomas  Singapore  ...    5/7/2011 0:00:00
# 6       7890      6          John    Mylasia  ...   3/28/2015 0:00:00
# 7        200      7          Bill      India  ...   7/23/2016 0:00:00
# 8       1000      8        Thomas         US  ...   6/30/2016 0:00:00
# 9       1000      9          John         UK  ...   7/10/2017 0:00:00
# 10       567     10          Bill  Australia  ...   1/27/2012 0:00:00
# 11      1000     11        Thomas     Africa  ...   12/3/2010 0:00:00
# 12       892     12          John  Singapore  ...   6/13/2012 0:00:00
# 13       444     13          Bill    Mylasia  ...   6/30/2010 0:00:00
# 14        90     14        Thomas      India  ...   1/29/2012 0:00:00
# 15        90     15          John         US  ...   1/31/2015 0:00:00
# 16        90     16          Bill         UK  ...   8/20/2014 0:00:00
# 17        90     17        Thomas  Australia  ...    3/9/2017 0:00:00
# 18        85     18          John     Africa  ...    6/2/2016 0:00:00
# 19        85     19          Bill  Singapore  ...   5/23/2013 0:00:00
#
#        Total  Quantity  index  Sales Person    Country Region  \
# 0     100000       567      0          John      India  North
# 1     120000      3000      1          Bill         US  North
# 2     140000       345      2        Thomas         UK  North
# 3     160000      1000      3          John  Australia   East
# 4     180000       123      4          Bill     Africa   East
# 5     200000      1000      5        Thomas  Singapore   East
# 6    1000000      7890      6          John    Mylasia   West
# 7     240000       200      7          Bill      India   West
# 8   26000000      1000      8        Thomas         US   West
# 9     100000      1000      9          John         UK  North
# 10    120000       567     10          Bill  Australia  North
# 11    140000      1000     11        Thomas     Africa  North
# 12    160000       892     12          John  Singapore   East
# 13    180000       444     13          Bill    Mylasia   East
# 14    200000        90     14        Thomas      India   East
# 15    220000        90     15          John         US   West
# 16    240000        90     16          Bill         UK   West
# 17    260000        90     17        Thomas  Australia   West
# 18    140000        85     18          John     Africa  North
# 19    150000        85     19          Bill  Singapore  North
#
#       Date of Purchase     Total  Quantity
# 0   11/18/2018 0:00:00    100000       567
# 1    2/24/2012 0:00:00    120000      3000
# 2   11/25/2011 0:00:00    140000       345
# 3     9/3/2014 0:00:00    160000      1000
# 4    1/14/2015 0:00:00    180000       123
# 5     5/7/2011 0:00:00    200000      1000
# 6    3/28/2015 0:00:00   1000000      7890
# 7    7/23/2016 0:00:00    240000       200
# 8    6/30/2016 0:00:00  26000000      1000
# 9    7/10/2017 0:00:00    100000      1000
# 10   1/27/2012 0:00:00    120000       567
# 11   12/3/2010 0:00:00    140000      1000
# 12   6/13/2012 0:00:00    160000       892
# 13   6/30/2010 0:00:00    180000       444
# 14   1/29/2012 0:00:00    200000        90
# 15   1/31/2015 0:00:00    220000        90
# 16   8/20/2014 0:00:00    240000        90
# 17    3/9/2017 0:00:00    260000        90
# 18    6/2/2016 0:00:00    140000        85
# 19   5/23/2013 0:00:00    150000        85
#
# [20 rows x 21 columns]

# %%
df.append([new_df, new_df1, new_df2])
# Out:
# C:\Users\gargm\AppData\Local\Temp\ipykernel_1308\840742941.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append([new_df, new_df1, new_df2])
#     index Sales Person    Country Region    Date of Purchase   Total  Quantity
# 0       0         John      India  North  11/18/2018 0:00:00  100000       567
# 1       1         Bill         US  North   2/24/2012 0:00:00  120000      3000
# 2       2       Thomas         UK  North  11/25/2011 0:00:00  140000       345
# 3       3         John  Australia   East    9/3/2014 0:00:00  160000      1000
# 4       4         Bill     Africa   East   1/14/2015 0:00:00  180000       123
# ..    ...          ...        ...    ...                 ...     ...       ...
# 15     15         John         US   West   1/31/2015 0:00:00  220000        90
# 16     16         Bill         UK   West   8/20/2014 0:00:00  240000        90
# 17     17       Thomas  Australia   West    3/9/2017 0:00:00  260000        90
# 18     18         John     Africa  North    6/2/2016 0:00:00  140000        85
# 19     19         Bill  Singapore  North   5/23/2013 0:00:00  150000        85
#
# [80 rows x 7 columns]
